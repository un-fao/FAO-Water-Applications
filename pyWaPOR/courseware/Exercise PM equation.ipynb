# %% [markdown]
# This notebook is designed to be used on Google Colab: [![](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/wateraccounting/FAO-Water-Applications/blob/main/pyWaPOR/courseware/Exercise%20PM%20equation.ipynb?target="_blank")
#
# # Exercise: Penman-Monteith equation
#
# This notebook shows an exercise to interact with the factors in Penman-Monteith equation in pywapor model to see the impacts on the resulted evaporation and transpiration.
#
# To run this notebook, select Runtime > Run all, or press CTRL + F9.

# %%
# !pip install pywapor
# Out:
# Requirement already satisfied: pywapor in /usr/local/lib/python3.10/dist-packages (3.5.5)
# Requirement already satisfied: netcdf4 in /usr/local/lib/python3.10/dist-packages (from pywapor) (1.7.1)
# Requirement already satisfied: gdal<4,>=3 in /usr/local/lib/python3.10/dist-packages (from pywapor) (3.6.4)
# Requirement already satisfied: xarray in /usr/local/lib/python3.10/dist-packages (from pywapor) (2023.7.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pywapor) (1.25.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from pywapor) (2.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from pywapor) (2.31.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from pywapor) (3.7.1)
# Requirement already satisfied: pyproj in /usr/local/lib/python3.10/dist-packages (from pywapor) (3.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from pywapor) (1.11.4)
# Requirement already satisfied: pycurl in /usr/local/lib/python3.10/dist-packages (from pywapor) (7.45.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from pywapor) (1.4.2)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.10/dist-packages (from pywapor) (0.0.2)
# Requirement already satisfied: rasterio in /usr/local/lib/python3.10/dist-packages (from pywapor) (1.3.10)
# Requirement already satisfied: bottleneck in /usr/local/lib/python3.10/dist-packages (from pywapor) (1.4.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from pywapor) (4.66.4)
# Requirement already satisfied: dask in /usr/local/lib/python3.10/dist-packages (from pywapor) (2023.8.1)
# Requirement already satisfied: rioxarray>=0.15.5 in /usr/local/lib/python3.10/dist-packages (from pywapor) (0.15.5)
# Requirement already satisfied: cryptography in /usr/local/lib/python3.10/dist-packages (from pywapor) (42.0.8)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.10/dist-packages (from pywapor) (5.3.3)
# Requirement already satisfied: cdsapi in /usr/local/lib/python3.10/dist-packages (from pywapor) (0.7.0)
# Requirement already satisfied: shapely in /usr/local/lib/python3.10/dist-packages (from pywapor) (2.0.4)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from pywapor) (4.9.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from pywapor) (1.2.2)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from pywapor) (0.58.1)
# Requirement already satisfied: xmltodict in /usr/local/lib/python3.10/dist-packages (from pywapor) (0.13.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from rioxarray>=0.15.5->pywapor) (24.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from pyproj->pywapor) (2024.6.2)
# Requirement already satisfied: affine in /usr/local/lib/python3.10/dist-packages (from rasterio->pywapor) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from rasterio->pywapor) (23.2.0)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.10/dist-packages (from rasterio->pywapor) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from rasterio->pywapor) (0.7.2)
# Requirement already satisfied: snuggs>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from rasterio->pywapor) (1.4.7)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.10/dist-packages (from rasterio->pywapor) (1.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from rasterio->pywapor) (67.7.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->pywapor) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pywapor) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pywapor) (2024.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4->pywapor) (4.12.3)
# Requirement already satisfied: cads-api-client>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from cdsapi->pywapor) (1.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->pywapor) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->pywapor) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->pywapor) (2.0.7)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography->pywapor) (1.16.0)
# Requirement already satisfied: cloudpickle>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from dask->pywapor) (2.2.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.10/dist-packages (from dask->pywapor) (2023.6.0)
# Requirement already satisfied: partd>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from dask->pywapor) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from dask->pywapor) (6.0.1)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from dask->pywapor) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /usr/local/lib/python3.10/dist-packages (from dask->pywapor) (7.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pywapor) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pywapor) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pywapor) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pywapor) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pywapor) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pywapor) (3.1.2)
# Requirement already satisfied: cftime in /usr/local/lib/python3.10/dist-packages (from netcdf4->pywapor) (1.6.4)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->pywapor) (0.41.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pywapor) (3.5.0)
# Requirement already satisfied: multiurl in /usr/local/lib/python3.10/dist-packages (from cads-api-client>=0.9.2->cdsapi->pywapor) (0.3.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from cads-api-client>=0.9.2->cdsapi->pywapor) (4.12.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography->pywapor) (2.22)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.13.0->dask->pywapor) (3.19.2)
# Requirement already satisfied: locket in /usr/local/lib/python3.10/dist-packages (from partd>=1.2.0->dask->pywapor) (1.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->pywapor) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4->pywapor) (2.5)

# %%
import ipywidgets as widgets
from ipywidgets import HBox, VBox
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display

# %%
import pywapor
from pywapor.et_look_v2_v3.neutral import initial_daily_evaporation as evaporation
from pywapor.et_look_v2_v3.neutral import initial_daily_transpiration as transpiration
from pywapor.et_look_v2_v3.radiation import net_radiation_canopy,net_radiation_soil

# %% [markdown]
# # ETLook Penman-Monteith equation
#
# In ETLook model, the Penman-Monteith equation for transpiration and evaporation are as follows:
#
# $E=\frac{\Delta\left(R_{n, \text { soil }}-G\right)+\rho c_p\left(\frac{\Delta_e}{r_{a, soil}}\right)}{\Delta+\gamma\left(1+\frac{r_{soil}}{r_{a,soil}}\right)}$
#
# $T=\frac{\Delta\left(R_{n, \text { canopy }}\right)+\rho c_p\left(\frac{\Delta_e}{r_{a, canopy}}\right)}{\Delta+\gamma\left(1+\frac{r_{canopy}}{r_{a, canopy}}\right)}$
#
# ## List of variables
#
# | Symbol |  Variable name | Variable code |
# | ------ | --------- | --------- |
# | $R_n$ | Net radiation | rn |
# | $G$ | Soil heat flux |  g0 |
# | $\Delta$ | slope saturated vapor pressure |  ssvp |
# | $\rho$ | Air density |  ad |
# | $\Delta_e$ | Vapor Pressure Deficit |  vpd |
# | $\gamma$ | Psychrometric constant |  psy |
# | $r_{soil}$ | soil surface resistance |  r_soil |
# | $r_{a,soil}$ | soil aerodynamic resistance |  ra_soil |
# | $r_{canopy}$ | canopy surface resistance |  r_canopy |
# | $r_{a,canopy}$ | canopy aerodynamic resistance |  ra_canopy |
# | $f_{soil}$ | Soil fraction |  sf_soil |

# %% [markdown]
# # Impacts of different factors on evaporation and transpiration
#
# The cell below launches the interactive graph of evaporation and transpiration. Interact with different factors using the scroll bars, see how the bar chart changes, and answer the questions at the end. For the purpose of this exercise, we are using hypothetical values of the parameters, not based on actual values.

# %%
# @title
# physical range of daily value (Ref, YYYY)
@widgets.interact(
sf_soil = (0.01,1), #[-]
rn = (-100,900), #[Wm-2] (reference: )
g0 = (10,100),#[Wm-2] (reference: )
ssvp = (0.01,1),#[mbar K-1] (reference: )
ad = (0.01,1),#[kg m-3] (reference: )
vpd = (0.01,1),#[mbar] (reference: )
psy = (0.1,1),#[mbar K-1] (constant??)
r_soil = (0.1,1),#[m s-1] (reference: )
ra_soil = (0.1,1),#[m s-1] (reference: )
r_canopy = (0.1,1),#[m s-1] (reference: )
ra_canopy = (0.1,1),#[m s-1] (reference: )

)
def plot(sf_soil=0.5,
         rn=200,
         g0=50,
         ssvp=0.5,
         ad=0.5,
         vpd=0.5,
         psy=0.5,
         r_soil=0.5,
         ra_soil=0.5,
         r_canopy=0.5,
         ra_canopy=0.5

        ):
    rn_soil=net_radiation_soil(rn,sf_soil)
    rn_canopy=net_radiation_canopy(rn,sf_soil)
    e = evaporation(rn_soil, g0, ssvp, ad, vpd, psy, r_soil, ra_soil)
    t = transpiration(rn_canopy, ssvp, ad, vpd, psy, r_canopy, ra_canopy)
    et=e+t
    # plot e, t, et
    fig, ax = plt.subplots(1, 1, figsize=(6, 3))
    ax.bar([1,2,3], [e,t,et],
           color=['orange','green','blue'],
           tick_label=['Evaporation','Transpiration','Evapotranspiration']
            )
    ax.grid(True)
    ax.set_ylim(0,1000)
    plt.ylabel('Latent heat flux ($W/m^2$)')
    plt.show()
    # plot e, t, et when change One-At-a-Time
# Out:
# interactive(children=(FloatSlider(value=0.5, description='sf_soil', max=1.0, min=0.01), IntSlider(value=200, d…

# %% [markdown]
# # ❓ Questions

# %%
# @title 1. Which factor does not change total evapotranspiration, but change the distribution between evaporation and transpiration? { display-mode: "form" }

Answer = 'Select an answer' # @param ["Select an answer", "Net radiation (rn)", "Soil fraction (sf_soil)", "Psychrometric constant (psy)","Air density (ad)"]
if Answer == 'Select an answer':
  print("Please select your answer")
elif Answer ==  "Soil fraction (sf_soil)":
  print("Correct!")
else:
  print("Not correct! Try interacting with the graph and answer again.")
# Out:
# Please select your answer

# %%
# @title 2. Which factor only changes evaporation, but not transpiration? { display-mode: "form" }

Answer = 'Select an answer' # @param ["Select an answer", "Vapor Pressure Deficit (vpd)", "Soil fraction (sf)", "Soil heat flux (g0)","None of the above"]
if Answer == 'Select an answer':
  print("Please select your answer")
elif Answer ==  "Soil heat flux (g0)":
  print("Correct!")
else:
  print("Not correct! Try interacting with the graph and answer again.")
# Out:
# Please select your answer

# %%
# @title 3. Which factor when increased, cause evapotranspiration to decrease? { display-mode: "form" }

Answer = 'Select an answer' # @param ["Select an answer", "air density (ad)", "Net radiation (rn)","slope saturated vapor pressure (ssvp)", "None of the above"]
if Answer == 'Select an answer':
  print("Please select your answer")
elif Answer ==  "slope saturated vapor pressure (ssvp)":
  print("Correct!")
else:
  print("Not correct! Try interacting with the graph and answer again.")
# Out:
# Please select your answer
